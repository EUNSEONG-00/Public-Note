# %% [markdown]
# # 특성 공학 종합 실습 (분류)

# %%
import pandas as pd

# %%
df1 = pd.read_csv('preprocessing_data.csv')

# %%
df1['target_binom'].value_counts()
# Out:
# target_binom
# 0.0    688
# 1.0     64
# Name: count, dtype: int64

# %%
Y = df1['target_binom']
X = df1[['Vapor','resist_target', 'Line_CD', 'UV_type',
         'Etching_rate', 'thickness', 'Temp_Etching']]

# %%
# !pip install --user imblearn  
# Imbalanced Data Sampling 수행 라이브러리

# %%
conda install -c conda-forge imbalanced-learn=0.11.0
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - imbalanced-learn=0.11.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.2.2   |       h56e8100_0         152 KB  conda-forge
#     certifi-2024.2.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         309 KB
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.08.22~ --> conda-forge::ca-certificates-2024.2.2-h56e8100_0
#   certifi            pkgs/main/win-64::certifi-2023.7.22-p~ --> conda-forge/noarch::certifi-2024.2.2-pyhd8ed1ab_0
#   imbalanced-learn                   0.10.1-py311haa95532_1 --> 0.11.0-py311haa95532_1
# ...

# %%
# 학습 데이터와 검증데이터 분할
from sklearn.model_selection import train_test_split
# 특성공학 + 학습 Pipe 구성
# 연속형 데이터와 범주형 데이터를 따로 처리하는 Pipe
from sklearn.compose  import make_column_transformer
# 각각의 처리기법을 파이프 형태로 구성
from sklearn.pipeline import make_pipeline
# 연속형 데이터 전처리 
from sklearn.impute   import KNNImputer
from sklearn.preprocessing import MinMaxScaler
# 범주형 데이터 전처리 
from sklearn.impute   import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
# Imbalanced Data Sampling
from imblearn.over_sampling import SMOTE 
# 학습 알고리즘으로 학습 (분류 알고리즘)
from sklearn.tree import DecisionTreeClassifier
# 교차검증 + Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV
# 평가 지표
from sklearn.metrics import classification_report
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 15
#      13 from sklearn.preprocessing import OneHotEncoder
#      14 # Imbalanced Data Sampling
# ---> 15 from imblearn.over_sampling import SMOTE
#      16 # 학습 알고리즘으로 학습 (분류 알고리즘)
#      17 from sklearn.tree import DecisionTreeClassifier
#
# File C:\ProgramData\anaconda3\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state=1234)

# %%
numeric_list = ['resist_target', 'Line_CD', 'Etching_rate', 'thickness', 'Temp_Etching']
catagory_list = ['Vapor', 'UV_type']

# %%
numeric_pipe = make_pipeline( KNNImputer(), MinMaxScaler() )
category_pipe = make_pipeline( SimpleImputer(strategy='most_frequent'), OneHotEncoder() )

preprocessing_pipe = make_column_transformer( (numeric_pipe, numeric_list), (category_pipe, catagory_list))

# %%
pipe_model = make_pipeline(preprocessing_pipe, SMOTE(), DecisionTreeClassifier() )
pipe_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pipe_model = make_pipeline(preprocessing_pipe, SMOTE(), DecisionTreeClassifier() )
#
# NameError: name 'SMOTE' is not defined

# %%
hyerparameter = {'decisiontreeclssifier__max_depth':range(5,11),
                 'decisiontreeclassifier__min_samples_split':range(5,11),
                 'decisiontreeclassifier__min_samples_leaf':range(5,11)}
# 'n_jobs' : 병렬 분산 해서 처리하는 기법
# 'scoring' : 어떤 지표를 기준으로 베스트 모델을 선정할 것인지 기준 스코어를 설정할 수 있는 함수기능
grid_model = GridSearchCV(pipe_model, param_grid=hyerparameter, cv=3, 
                          n_jobs= -1, scoring='f1')
grid_model.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       1 hyerparameter = {'decisiontreeclssifier__max_depth':range(5,11),
#       2                  'decisiontreeclassifier__min_samples_split':range(5,11),
#       3                  'decisiontreeclassifier__min_samples_leaf':range(5,11)}
# ----> 4 grid_model = GridSearchCV(pipe_model, param_grid=hyerparameter, cv=3, n_jobs= -1)
#       5 grid_model.fit(X_train, Y_train)
#
# NameError: name 'GridSearchCV' is not defined

# %%
best_model = grid_model.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 best_model = grid_model.best_estimator_
#
# NameError: name 'grid_model' is not defined

# %%
def evaluation_cla(model):
    Y_train_pred = model.predict(X_train)
    Y_test_pred = model.predict(X_test)
    print('학습 능력 평가 : ')
    print(classification_report(Y_train, Y_train_pred))
    print('일반화 능력 평가 : ')
    print(classification_report(Y_test, Y_test_pred))

# %%
evaluation_cla(best_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 evaluation_cla(best_model)
#
# NameError: name 'best_model' is not defined

# %% [markdown]
# **모델을 파일 형태로 저장**

# %%
import pickle

# %%
pickle.dump(best_model, open('model.sav', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pickle.dump(best_model, open('model.sav', 'wb'))
#
# NameError: name 'best_model' is not defined
